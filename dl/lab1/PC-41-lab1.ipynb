# %%
# Name: Rohit Saini
# Roll No.: PC41
# Panel: C
# ERP Id.: 1032200897

# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

warnings.filterwarnings('ignore')

# %%
state_data = pd.read_csv("state.csv")
state_data.columns
# Out:
# Index(['TimeStamp', 'Punjab', 'Haryana', 'Rajasthan', 'Delhi', 'UP',
#        'Uttarakhand', 'HP', 'J&K', 'Chandigarh', 'Chhattisgarh', 'Gujarat',
#        'MP', 'Maharashtra', 'Goa', 'DNH', 'Andhra Pradesh', 'Telangana',
#        'Karnataka', 'Kerala', 'Tamil Nadu', 'Pondy', 'Bihar', 'Jharkhand',
#        'Odisha', 'West Bengal', 'Sikkim', 'Arunachal Pradesh', 'Assam',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Tripura'],
#       dtype='object')

# %%
# performing exploratory data analysis
state_data.head()
# Out:
#              TimeStamp  Punjab  Haryana  Rajasthan  Delhi     UP  Uttarakhand  \
# 0  02/01/2019 00:00:00   119.9    130.3      234.1   85.8  313.9         40.7
# 1  03/01/2019 00:00:00   121.9    133.5      240.2   85.5  311.8         39.3
# 2  04/01/2019 00:00:00   118.8    128.2      239.8   83.5  320.7         38.1
# 3  05/01/2019 00:00:00   121.0    127.5      239.1   79.2  299.0         39.2
# 4  06/01/2019 00:00:00   121.4    132.6      240.4   76.6  286.8         39.2
#
#      HP   J&K  Chandigarh  ...  Odisha  West Bengal  Sikkim  \
# 0  30.0  52.5         5.0  ...    70.2        108.2     2.0
# 1  30.1  54.1         4.9  ...    67.9        110.2     1.9
# 2  30.1  53.2         4.8  ...    66.3        106.8     1.7
# 3  30.2  51.5         4.3  ...    65.8        107.0     2.0
# 4  31.0  53.2         4.3  ...    62.9        106.4     2.0
#
#    Arunachal Pradesh  Assam  Manipur  Meghalaya  Mizoram  Nagaland  Tripura
# 0                2.1   21.7      2.7        6.1      1.9       2.2      3.4
# 1                2.2   23.4      2.4        6.5      1.8       2.2      3.6
# 2                2.2   21.7      2.4        6.3      1.7       2.2      3.5
# 3                2.2   22.5      2.7        5.7      1.8       2.3      3.5
# 4                2.2   21.7      2.7        6.2      1.9       2.3      3.3
#
# [5 rows x 34 columns]

# %%
# checking for null values
state_data.isnull().sum()
# Out:
# TimeStamp            0
# Punjab               0
# Haryana              0
# Rajasthan            0
# Delhi                0
# UP                   0
# Uttarakhand          0
# HP                   0
# J&K                  0
# Chandigarh           0
# Chhattisgarh         0
# Gujarat              0
# MP                   0
# Maharashtra          0
# Goa                  0
# DNH                  0
# Andhra Pradesh       0
# Telangana            0
# Karnataka            0
# Kerala               0
# Tamil Nadu           0
# Pondy                0
# Bihar                0
# Jharkhand            0
# Odisha               0
# West Bengal          0
# Sikkim               0
# Arunachal Pradesh    0
# Assam                0
# Manipur              0
# Meghalaya            0
# Mizoram              0
# Nagaland             0
# Tripura              0
# dtype: int64

# %%
# checking for unique values
state_data.nunique()
# Out:
# TimeStamp            474
# Punjab               383
# Haryana              374
# Rajasthan            367
# Delhi                328
# UP                   426
# Uttarakhand          201
# HP                   138
# J&K                  171
# Chandigarh            46
# Chhattisgarh         269
# Gujarat              387
# MP                   392
# Maharashtra          406
# Goa                   69
# DNH                   81
# Andhra Pradesh       313
# Telangana            372
# Karnataka            381
# Kerala               227
# Tamil Nadu           397
# Pondy                 56
# Bihar                288
# Jharkhand             92
# Odisha               278
# West Bengal          354
# Sikkim                22
# Arunachal Pradesh     17
# Assam                167
# Manipur               16
# Meghalaya             36
# Mizoram               11
# Nagaland              12
# Tripura               38
# dtype: int64

# %%
state_data.describe()
# Out:
#            Punjab     Haryana   Rajasthan       Delhi          UP  \
# count  479.000000  479.000000  479.000000  479.000000  479.000000
# mean   139.283925  137.508559  218.463257   82.746764  312.864927
# std     55.117346   37.161544   27.747140   25.437537   65.522780
# min     56.100000   64.800000  105.800000   41.800000  186.800000
# 25%    103.800000  114.950000  205.800000   63.450000  263.750000
# 50%    117.900000  126.500000  223.200000   72.200000  289.200000
# 75%    157.900000  157.600000  238.100000  103.500000  368.400000
# max    291.700000  224.500000  278.000000  139.100000  471.800000
#
#        Uttarakhand          HP         J&K  Chandigarh  Chhattisgarh  ...  \
# count   479.000000  479.000000  479.000000  479.000000    479.000000  ...
# mean     36.026514   26.487474   44.264301    4.114823     83.729645  ...
# std       6.766950    4.886243    4.854024    1.117365     10.103077  ...
# min      16.800000   11.800000   17.800000    2.200000     37.200000  ...
# 25%      33.700000   25.600000   41.500000    3.300000     75.700000  ...
# 50%      36.900000   28.000000   44.100000    3.800000     82.500000  ...
# 75%      40.300000   29.650000   47.600000    4.900000     91.400000  ...
# max      53.200000   34.000000   54.200000    6.800000    111.600000  ...
#
#            Odisha  West Bengal      Sikkim  Arunachal Pradesh       Assam  \
# count  479.000000   479.000000  479.000000         479.000000  479.000000
# mean    80.256576   138.291858    1.291023           2.106263   24.902088
# std     10.673270    27.877885    0.368735           0.235283    4.658056
# min     51.100000    51.500000    0.300000           1.100000   12.200000
# 25%     71.650000   114.550000    1.050000           2.000000   22.100000
# 50%     79.700000   130.400000    1.300000           2.200000   23.500000
# 75%     88.200000   164.100000    1.400000           2.200000   27.550000
# max    109.600000   198.500000    2.800000           2.700000   38.000000
#
#           Manipur   Meghalaya     Mizoram    Nagaland     Tripura
# count  479.000000  479.000000  479.000000  479.000000  479.000000
# mean     2.494990    5.645094    1.707307    2.162422    4.090605
# std      0.225322    0.732203    0.144960    0.144231    0.738776
# min      1.500000    3.300000    1.200000    1.400000    1.400000
# 25%      2.400000    5.300000    1.600000    2.100000    3.500000
# 50%      2.500000    5.800000    1.700000    2.200000    3.900000
# 75%      2.600000    6.100000    1.800000    2.200000    4.600000
# max      3.200000    6.900000    2.200000    2.700000    6.600000
#
# [8 rows x 33 columns]

# %%
state_data
# Out:
#                TimeStamp  Punjab  Haryana  Rajasthan  Delhi     UP  \
# 0    02/01/2019 00:00:00   119.9    130.3      234.1   85.8  313.9
# 1    03/01/2019 00:00:00   121.9    133.5      240.2   85.5  311.8
# 2    04/01/2019 00:00:00   118.8    128.2      239.8   83.5  320.7
# 3    05/01/2019 00:00:00   121.0    127.5      239.1   79.2  299.0
# 4    06/01/2019 00:00:00   121.4    132.6      240.4   76.6  286.8
# ..                   ...     ...      ...        ...    ...    ...
# 474  02/07/2020 00:00:00   108.5    109.0      219.8   59.3  242.3
# 475  03/07/2020 00:00:00   235.3    204.6      203.2  122.8  425.6
# 476  04/07/2020 00:00:00   242.9    215.7      212.6  129.2  434.0
# 477  05/07/2020 00:00:00   246.2    217.8      225.5  130.3  414.1
# 478  01/08/2020 00:00:00   214.3    208.0      225.7  128.7  439.6
#
#      Uttarakhand    HP   J&K  Chandigarh  ...  Odisha  West Bengal  Sikkim  \
# 0           40.7  30.0  52.5         5.0  ...    70.2        108.2     2.0
# 1           39.3  30.1  54.1         4.9  ...    67.9        110.2     1.9
# 2           38.1  30.1  53.2         4.8  ...    66.3        106.8     1.7
# 3           39.2  30.2  51.5         4.3  ...    65.8        107.0     2.0
# 4           39.2  31.0  53.2         4.3  ...    62.9        106.4     2.0
# ..           ...   ...   ...         ...  ...     ...          ...     ...
# 474         32.1  26.4  45.4         3.1  ...    73.8        107.6     1.4
# 475         41.1  29.5  39.5         6.2  ...    94.8        171.8     0.9
# 476         43.9  30.7  41.2         6.5  ...    91.1        178.4     0.9
# 477         41.1  30.7  40.3         6.1  ...    93.6        172.2     1.0
# 478         42.8  29.9  38.6         5.7  ...    93.6        171.8     1.0
#
#      Arunachal Pradesh  Assam  Manipur  Meghalaya  Mizoram  Nagaland  Tripura
# 0                  2.1   21.7      2.7        6.1      1.9       2.2      3.4
# 1                  2.2   23.4      2.4        6.5      1.8       2.2      3.6
# 2                  2.2   21.7      2.4        6.3      1.7       2.2      3.5
# 3                  2.2   22.5      2.7        5.7      1.8       2.3      3.5
# 4                  2.2   21.7      2.7        6.2      1.9       2.3      3.3
# ..                 ...    ...      ...        ...      ...       ...      ...
# 474                2.1   21.1      2.5        6.1      1.7       2.2      3.5
# 475                2.5   35.5      2.4        5.0      1.7       2.0      4.7
# 476                2.4   36.1      2.5        4.9      1.7       2.4      5.0
# 477                2.2   34.0      2.6        5.1      1.8       2.2      5.2
# 478                2.4   33.3      2.5        5.3      1.9       2.5      5.2
#
# [479 rows x 34 columns]

# %%
state_data = state_data[['Goa', 'Gujarat', 'Maharashtra', 'DNH', 'Rajasthan']]
state_data
# Out:
#       Goa  Gujarat  Maharashtra   DNH  Rajasthan
# 0    12.8    319.5        428.6  18.6      234.1
# 1    13.7    316.7        419.6  18.2      240.2
# 2    12.6    301.9        395.8  16.7      239.8
# 3    13.0    313.2        411.1  17.6      239.1
# 4    12.9    320.7        408.6  18.6      240.4
# ..    ...      ...          ...   ...        ...
# 474  12.3    312.0        421.6  18.2      219.8
# 475   8.8    289.7        369.2  17.4      203.2
# 476   8.8    297.9        395.5  18.3      212.6
# 477   8.8    296.8        395.5  18.7      225.5
# 478  10.2    288.7        399.6  18.5      225.7
#
# [479 rows x 5 columns]

# %%
# checking for outliers
from scipy.stats import zscore
state_data.boxplot(figsize=(20, 8))
# Out:
# <Axes: >

# %%
# removing outliers
z = np.abs(zscore(state_data))
z

threshold = 3
print(np.where(z > 3))

state_data = state_data[(z < 3).all(axis=1)]
state_data
state_data.to_csv('state_consumption.csv', index=False)
# Out:
# (array([ 28,  28,  28,  29,  30,  31,  32,  33,  34,  35, 143, 144, 144,
#        145, 145, 145, 146, 146, 146, 300, 419, 420, 421, 422, 423, 424,
#        425], dtype=int64), array([1, 3, 4, 3, 3, 3, 3, 3, 3, 2, 0, 3, 4, 1, 3, 4, 1, 3, 4, 3, 3, 3,
#        3, 3, 3, 3, 3], dtype=int64))

# %%
states = ['Goa', 'Gujarat', 'Maharashtra', 'DNH', 'Rajasthan']
fig, axes = plt.subplots(nrows=len(states), ncols=1, figsize=(10, 12))

# plot the data by day for each state with random color
for i, state in enumerate(states):
    axes[i].plot(state_data[state], marker='.', linestyle='-',
                 linewidth=0.5, label=state, color=np.random.rand(3,))
    axes[i].set_ylabel('Electricity')
    axes[i].set_title(state)
    axes[i].legend()
# set some figure-level properties
fig.tight_layout()

# set some axes-level properties
axes[0].set_xticklabels([])
axes[1].set_xticklabels([])
axes[2].set_xticklabels([])
axes[0].set_xlabel('Date')
axes[1].set_xlabel('Date')
axes[2].set_xlabel('Date')
axes[3].set_xlabel('Date')

axes[0].set_ylabel('Electricity - Units')
axes[1].set_ylabel('Electricity - Units')
axes[2].set_ylabel('Electricity - Units')
axes[3].set_ylabel('Electricity - Units')

plt.show()

# %%
# add the goa , gujarat , maharashtra and dnh data to get the total electricity in west zone
from sklearn.preprocessing import MinMaxScaler
west_zone = state_data['Goa'] + state_data['Gujarat'] + \
    state_data['Maharashtra'] + state_data['DNH'] + state_data['Rajasthan']
# west_zone
# scale the data
scaler = MinMaxScaler(feature_range=(0, 1))
west_zone = scaler.fit_transform(np.array(west_zone).reshape(-1, 1))
# west_zone
# data is of 503 days
# len(west_zone)

# %%
# plot the west zone
# plot the data by day for each state with random color
plt.plot(west_zone, marker='.', linestyle='-', linewidth=0.5,
         label='West Zone', color=np.random.rand(3,))
plt.ylabel('Electricity')
plt.title('West Zone')
plt.legend()
plt.show()

# %%
# using decision tree regressor to predict the electricity in west zone
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split

# split the data into train and test
X_train, X_test, y_train, y_test = train_test_split(
    state_data, west_zone, test_size=0.2, random_state=42)

# fit the model
model = DecisionTreeRegressor()
model.fit(X_train, y_train)

# predict the electricity in west zone
y_pred = model.predict(X_test)

# plot the actual and predicted electricity in west zone
plt.figure(figsize=(8, 6))
plt.plot(y_test, label='actual', color='blue', linewidth=3)
plt.plot(y_pred, label='prediction', color='orange', linewidth=3)
plt.ylabel('Electricity')
plt.legend()
plt.show()

# %%
# print the predicted electricity consumption in west zone for next 7 days
# print("Predicted electricity consumption in west zone for next 7 days:")
# print(model.predict(state_data.tail(7)))

# rescale the data
y_pred = scaler.inverse_transform(y_pred.reshape(-1, 1))
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

# print the actual and predicted electricity consumption in west zone for next 7 days
print("Actual electricity consumption in west zone for next 7 days:")
print(y_test[-7:])
print("Predicted electricity consumption in west zone for next 7 days:")
print(y_pred[-7:])
# Out:
# Actual electricity consumption in west zone for next 7 days:
# [[ 947. ]
#  [1158.1]
#  [ 961.5]
#  [1184.7]
#  [1130.7]
#  [1025.1]
#  [1053.8]]
# Predicted electricity consumption in west zone for next 7 days:
# [[ 942. ]
#  [1159.6]
#  [ 967.2]
#  [1182.8]
#  [1113.1]
#  [1027. ]
#  [1052.1]]

# %%
# calculate the mean absolute error and accuracy of the model
from sklearn.metrics import mean_absolute_error, r2_score
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("Accuracy:", r2_score(y_test, y_pred))
# storing the accuracy in a variable
accuracy_decision_tree = r2_score(y_test, y_pred)
# Out:
# Mean Absolute Error: 14.651086956521768
# Accuracy: 0.9299249458036969

# %%
# using random forest regressor to predict the electricity in west zone
from sklearn.ensemble import RandomForestRegressor

# split the data into train and test
X_train, X_test, y_train, y_test = train_test_split(
    state_data, west_zone, test_size=0.2, random_state=42)

# fit the model
model = RandomForestRegressor()
model.fit(X_train, y_train)

# predict the electricity in west zone
y_pred = model.predict(X_test)

# plot the actual and predicted electricity in west zone
plt.figure(figsize=(8, 6))
plt.plot(y_test, label='actual', color='blue', linewidth=3)
plt.plot(y_pred, label='prediction', color='red', linewidth=3)
plt.ylabel('Electricity')
plt.legend()
plt.show()

# %%
y_pred = scaler.inverse_transform(y_pred.reshape(-1, 1))
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

# print the actual and predicted electricity consumption in west zone for next 7 days
print("Actual electricity consumption in west zone for next 7 days:")
print(y_test[-7:])
print("Predicted electricity consumption in west zone for next 7 days:")
print(y_pred[-7:])
# Out:
# Actual electricity consumption in west zone for next 7 days:
# [[ 947. ]
#  [1158.1]
#  [ 961.5]
#  [1184.7]
#  [1130.7]
#  [1025.1]
#  [1053.8]]
# Predicted electricity consumption in west zone for next 7 days:
# [[ 956.532]
#  [1156.041]
#  [ 972.696]
#  [1181.318]
#  [1123.259]
#  [1027.5  ]
#  [1050.213]]

# %%
# print accuracy and mean absolute error of the model
from sklearn.metrics import mean_absolute_error, r2_score
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("Accuracy:", r2_score(y_test, y_pred))
# storing the accuracy in a variable
accuracy_random_forest = r2_score(y_test, y_pred)
# Out:
# Mean Absolute Error: 7.93439130434788
# Accuracy: 0.9733486132139487

# %%
# using support vector regressor to predict the electricity in west zone
from sklearn.svm import SVR

# split the data into train and test
X_train, X_test, y_train, y_test = train_test_split(
    state_data, west_zone, test_size=0.2, random_state=42)

# fit the model
model = SVR()
model.fit(X_train, y_train)

# predict the electricity in west zone
y_pred = model.predict(X_test)

# plot the actual and predicted electricity in west zone
plt.figure(figsize=(8, 6))
plt.plot(y_test, label='actual', color='blue', linewidth=3)
plt.plot(y_pred, label='prediction', color='yellow', linewidth=3)
plt.ylabel('Electricity')
plt.legend()
plt.show()

# %%
# print accuracy and mean absolute error of the model
from sklearn.metrics import mean_absolute_error, r2_score
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("Accuracy:", r2_score(y_test, y_pred))
# storing the accuracy in a variable
accuracy_support_vector = r2_score(y_test, y_pred)
# Out:
# Mean Absolute Error: 0.031400179490163375
# Accuracy: 0.9540707769937778

# %%
# comparing the accuracy of all the models
print("Accuracy of Decision Tree Regressor:", accuracy_decision_tree)
print("Accuracy of Random Forest Regressor:", accuracy_random_forest)
print("Accuracy of Support Vector Regressor:", accuracy_support_vector)
# Out:
# Accuracy of Decision Tree Regressor: 0.9299249458036969
# Accuracy of Random Forest Regressor: 0.9733486132139487
# Accuracy of Support Vector Regressor: 0.9540707769937778

# %%
# ensemble learning
from sklearn.ensemble import VotingRegressor

# split the data into train and test
X_train, X_test, y_train, y_test = train_test_split(
    state_data, west_zone, test_size=0.2, random_state=42)

# fit the model
model = VotingRegressor([('dt', DecisionTreeRegressor()),
                        ('rf', RandomForestRegressor()), ('svr', SVR())])
model.fit(X_train, y_train)

# predict the electricity in west zone
y_pred = model.predict(X_test)

# plot the actual and predicted electricity in west zone
plt.figure(figsize=(8, 6))
plt.plot(y_test, label='actual', color='blue', linewidth=3)
plt.plot(y_pred, label='prediction', color='green', linewidth=3)
plt.ylabel('Electricity')
plt.legend()
plt.show()

# %%
# print accuracy and mean absolute error of the model
from sklearn.metrics import mean_absolute_error, r2_score
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("Accuracy:", r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 0.020353312001153905
# Accuracy: 0.9731358421131415
